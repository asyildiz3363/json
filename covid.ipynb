# %%
import requests

# %%
import json

# %%
response = requests.get("https://api.covid19api.com/summary").text

# %%
response_info = json.loads(response)

# %%
country_list = []
for country_info in response_info["Countries"]:
 country_list.append([country_info["Country"], country_info["TotalConfirmed"]])

# %%
country_list
# Out:
# [['Afghanistan', 157725],
#  ['Albania', 204928],
#  ['Algeria', 213745],
#  ['Andorra', 20549],
#  ['Angola', 65648],
#  ['Antigua and Barbuda', 4178],
#  ['Argentina', 5376642],
#  ['Armenia', 343157],
#  ['Australia', 242772],
#  ['Austria', 1242333],
#  ['Azerbaijan', 608060],
#  ['Bahamas', 22971],
#  ['Bahrain', 278257],
#  ['Bangladesh', 1580559],
#  ['Barbados', 27071],
#  ['Belarus', 679873],
#  ['Belgium', 1980120],
#  ['Belize', 31217],
#  ['Benin', 24907],
#  ['Bhutan', 2652],
#  ['Bolivia', 558565],
#  ['Bosnia and Herzegovina', 283784],
#  ['Botswana', 199864],
#  ['Brazil', 22201221],
#  ['Brunei Darussalam', 15376],
#  ['Bulgaria', 721819],
#  ['Burkina Faso', 16672],
#  ['Burundi', 21422],
#  ['Cambodia', 120397],
#  ['Cameroon', 107662],
#  ['Canada', 1527049],
#  ['Cape Verde', 38541],
#  ['Central African Republic', 11961],
#  ['Chad', 5703],
#  ['Chile', 1787676],
#  ['China', 112659],
#  ['Colombia', 5101466],
#  ['Comoros', 4589],
#  ['Congo (Brazzaville)', 19179],
#  ['Congo (Kinshasa)', 63388],
#  ['Costa Rica', 568428],
#  ['Croatia', 666162],
#  ['Cuba', 963885],
#  ['Cyprus', 143510],
#  ['Czech Republic', 2378728],
#  ["Côte d'Ivoire", 61998],
#  ['Denmark', 595688],
#  ['Djibouti', 13526],
#  ['Dominica', 6286],
#  ['Dominican Republic', 411014],
#  ['Ecuador', 535414],
#  ['Egypt', 372599],
#  ['El Salvador', 121384],
#  ['Equatorial Guinea', 13617],
#  ['Eritrea', 7713],
#  ['Estonia', 230514],
#  ['Ethiopia', 374402],
#  ['Fiji', 52604],
#  ['Finland', 211239],
#  ['France', 8564979],
#  ['Gabon', 37681],
#  ['Gambia', 10045],
#  ['Georgia', 901202],
#  ['Germany', 6741968],
#  ['Ghana', 131911],
#  ['Greece', 1022141],
#  ['Grenada', 5915],
#  ['Guatemala', 623195],
#  ['Guinea', 30814],
#  ['Guinea-Bissau', 6455],
#  ['Guyana', 38728],
#  ['Haiti', 25907],
#  ['Holy See (Vatican City State)', 27],
#  ['Honduras', 378685],
#  ['Hungary', 1213318],
#  ['Iceland', 20044],
#  ['India', 34726049],
#  ['Indonesia', 4259857],
#  ['Iran, Islamic Republic of', 6165454],
#  ['Iraq', 2089669],
#  ['Ireland', 640548],
#  ['Israel', 1353281],
#  ['Italy', 5308180],
#  ['Jamaica', 91927],
#  ['Japan', 1728540],
#  ['Jordan', 1027844],
#  ['Kazakhstan', 1065538],
#  ['Kenya', 258557],
#  ['Kiribati', 2],
#  ['Korea (South)', 551551],
#  ['Kuwait', 413891],
#  ['Kyrgyzstan', 184094],
#  ['Lao PDR', 94554],
#  ['Latvia', 264965],
#  ['Lebanon', 696168],
#  ['Lesotho', 23903],
#  ['Liberia', 5844],
#  ['Libya', 380464],
#  ['Liechtenstein', 5593],
#  ['Lithuania', 497643],
#  ['Luxembourg', 95759],
#  ['Macedonia, Republic of', 220467],
#  ['Madagascar', 45794],
#  ['Malawi', 63408],
#  ['Malaysia', 2707402],
#  ['Maldives', 93629],
#  ['Mali', 18938],
#  ['Malta', 41059],
#  ['Marshall Islands', 4],
#  ['Mauritania', 39964],
#  ['Mauritius', 22769],
#  ['Mexico', 3924638],
#  ['Micronesia, Federated States of', 1],
#  ['Moldova', 371410],
#  ['Monaco', 4114],
#  ['Mongolia', 386258],
#  ['Montenegro', 160457],
#  ['Morocco', 952189],
#  ['Mozambique', 156729],
#  ['Myanmar', 527714],
#  ['Namibia', 134154],
#  ['Nepal', 825176],
#  ['Netherlands', 2936761],
#  ['New Zealand', 13319],
#  ['Nicaragua', 17391],
#  ['Niger', 7185],
#  ['Nigeria', 221071],
#  ['Norway', 339008],
#  ['Oman', 304783],
#  ['Pakistan', 1290491],
#  ['Palau', 8],
#  ['Palestinian Territory', 465094],
#  ['Panama', 481824],
#  ['Papua New Guinea', 35966],
#  ['Paraguay', 464004],
#  ['Peru', 2258456],
#  ['Philippines', 2837016],
#  ['Poland', 3903445],
#  ['Portugal', 1211130],
#  ['Qatar', 246024],
#  ['Republic of Kosovo', 161235],
#  ['Romania', 1796230],
#  ['Russian Federation', 9955308],
#  ['Rwanda', 101030],
#  ['Saint Kitts and Nevis', 2798],
#  ['Saint Lucia', 13127],
#  ['Saint Vincent and Grenadines', 5723],
#  ['Samoa', 3],
#  ['San Marino', 6915],
#  ['Sao Tome and Principe', 3735],
#  ['Saudi Arabia', 550542],
#  ['Senegal', 74115],
#  ['Serbia', 1279445],
#  ['Seychelles', 24047],
#  ['Sierra Leone', 6434],
#  ['Singapore', 274972],
#  ['Slovakia', 1310588],
#  ['Slovenia', 445228],
#  ['Solomon Islands', 20],
#  ['Somalia', 23074],
#  ['South Africa', 3255816],
#  ['South Sudan', 13049],
#  ['Spain', 5422168],
#  ['Sri Lanka', 577724],
#  ['Sudan', 45112],
#  ['Suriname', 51323],
#  ['Swaziland', 57842],
#  ['Sweden', 1246755],
#  ['Switzerland', 1165778],
#  ['Syrian Arab Republic (Syria)', 49565],
#  ['Taiwan, Republic of China', 16771],
#  ['Tajikistan', 17493],
#  ['Tanzania, United Republic of', 26483],
#  ['Thailand', 2185497],
#  ['Timor-Leste', 19830],
#  ['Togo', 26466],
#  ['Tonga', 1],
#  ['Trinidad and Tobago', 83130],
#  ['Tunisia', 720518],
#  ['Turkey', 9102294],
#  ['Uganda', 128369],
#  ['Ukraine', 3764485],
#  ['United Arab Emirates', 743352],
#  ['United Kingdom', 11161497],
#  ['United States of America', 50513428],
#  ['Uruguay', 403582],
#  ['Uzbekistan', 196522],
#  ['Vanuatu', 7],
#  ['Venezuela (Bolivarian Republic)', 439935],
#  ['Viet Nam', 1493237],
#  ['Yemen', 10086],
#  ['Zambia', 213139],
#  ['Zimbabwe', 182057]]
